# %%
import pymongo

session = pymongo.MongoClient().get_database('tools_db').get_collection('tencent_chinese_word2vec')
session.find_one({'word': '浙江师范大学'})
# Out:
# {'_id': ObjectId('630f541a68ffe86bf3ec0602'),
#  'word': '浙江师范大学',
#  'vector': [0.057503,
#   0.039238,
#   0.149536,
#   -0.056658,
#   -0.159554,
#   -0.231556,
#   0.08676,
#   0.045527,
#   -0.100056,
#   0.435212,
#   -0.019352,
#   0.227914,
#   -0.222157,
#   -0.14578,
#   -0.099586,
#   -0.38306,
#   0.171619,
#   0.365664,
#   0.19457,
#   0.869841,
#   0.9674,
#   0.466123,
#   0.383266,
#   -0.015868,
#   0.411461,
#   0.253496,
#   -0.424501,
#   0.331757,
#   0.060674,
#   -0.328699,
#   0.099943,
#   -0.237416,
#   -0.019084,
#   -0.048059,
#   0.498831,
#   0.181586,
#   0.021702,
#   -0.259334,
#   -0.038699,
#   0.374491,
#   -0.405758,
#   0.582867,
#   0.321063,
#   -0.165123,
#   0.391074,
#   -0.015801,
#   0.230933,
#   -0.393489,
#   -0.144762,
#   -0.010182,
#   -0.015529,
#   0.017825,
#   0.224966,
#   -0.329659,
#   0.171041,
#   0.639555,
#   0.036092,
#   0.221024,
#   0.160209,
#   0.052652,
#   0.049739,
#   0.602718,
#   0.10925,
#   -0.070758,
# ...
